# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Global_Df = pd.read_csv('Global_Superstore2.csv',encoding='Latin-1')

# %%
Global_Df.head()
# Out:
#    Row ID         Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891  31-07-2012  31-07-2012      Same Day    RH-19495
# 1   26341    IN-2013-77878  05-02-2013  07-02-2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  17-10-2013  18-10-2013   First Class    CR-12730
# 3   13524  ES-2013-1579342  28-01-2013  30-01-2013   First Class    KM-16375
# 4   47221     SG-2013-4320  05-11-2013  06-11-2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
Global_Df.dropna(inplace=True)
Global_Df.drop(columns=['Row ID','Order ID','Customer Name','Country','Market'],inplace=True)
Global_Df['Postal Code'] =Global_Df['Postal Code'].astype(str)

# %%
Global_Df.reset_index(level=False,drop='index',inplace=True)

# %%
Global_Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order Date      9994 non-null   object
#  1   Ship Date       9994 non-null   object
#  2   Ship Mode       9994 non-null   object
#  3   Customer ID     9994 non-null   object
#  4   Segment         9994 non-null   object
#  5   City            9994 non-null   object
#  6   State           9994 non-null   object
#  7   Postal Code     9994 non-null   object
#  8   Region          9994 non-null   object
#  9   Product ID      9994 non-null   object
#  10  Category        9994 non-null   object
#  11  Sub-Category    9994 non-null   object
#  12  Product Name    9994 non-null   object
#  13  Sales           9994 non-null   float64
#  14  Quantity        9994 non-null   int64
#  15  Discount        9994 non-null   float64
#  16  Profit          9994 non-null   float64
# ...

# %% [markdown]
# <div style="font-size:26px;text-align:center">Calculate summary statistics:</div>

# %%
Sales_data=Global_Df['Sales'].describe()
Profit_data=Global_Df['Profit'].describe()
Discount_data=Global_Df['Discount'].describe()
Shipping_Cost_data=Global_Df['Shipping Cost'].describe()

# %%
Sales_data
# Out:
# count     9994.000000
# mean       229.858001
# std        623.245101
# min          0.444000
# 25%         17.280000
# 50%         54.490000
# 75%        209.940000
# max      22638.480000
# Name: Sales, dtype: float64

# %%
Profit_data
# Out:
# count    9994.000000
# mean       28.656896
# std       234.260108
# min     -6599.978000
# 25%         1.728750
# 50%         8.666500
# 75%        29.364000
# max      8399.976000
# Name: Profit, dtype: float64

# %%
Shipping_Cost_data
# Out:
# count    9994.000000
# mean       23.831678
# std        58.962848
# min         0.010000
# 25%         1.490000
# 50%         5.100000
# 75%        19.985000
# max       933.570000
# Name: Shipping Cost, dtype: float64

# %%
Discount_data
# Out:
# count    9994.000000
# mean        0.156203
# std         0.206452
# min         0.000000
# 25%         0.000000
# 50%         0.200000
# 75%         0.200000
# max         0.800000
# Name: Discount, dtype: float64

# %% [markdown]
# <div style="font-size:30px;text-align:center">Create histograms for each variable

# %%
plt.hist(Sales_data, bins=30, color='skyblue', alpha=0.75, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %%
plt.hist(Discount_data, bins=30, color='skyblue', alpha=0.75, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %%
plt.hist(Profit_data, bins=30, color='skyblue', alpha=0.75, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %%
plt.hist(Shipping_Cost_data, bins=30, color='skyblue', alpha=0.75, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %% [markdown]
# <div style="font-size:30px;text-align:center">Correlation matrix</div>

# %%
correlation_matrix = Global_Df.corr()
# Out:
# C:\Windows\Temp\ipykernel_3584\1141278215.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = Global_Df.corr()

# %%
correlation_matrix
# Out:
#                   Sales  Quantity  Discount    Profit  Shipping Cost
# Sales          1.000000  0.200795 -0.028190  0.479064       0.677279
# Quantity       0.200795  1.000000  0.008623  0.066253       0.221305
# Discount      -0.028190  0.008623  1.000000 -0.219487      -0.030117
# Profit         0.479064  0.066253 -0.219487  1.000000       0.283280
# Shipping Cost  0.677279  0.221305 -0.030117  0.283280       1.000000

# %%
plt.figure(figsize=(10, 8))  # Adjust the figure size as needed
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
sns.pairplot(Global_Df, vars=['Sales', 'Quantity', 'Profit','Discount'])
plt.figure(figsize=(20, 10))
plt.show()

# %% [markdown]
# <div style="font-size:30px;text-align:center">Categorical Variables</div>

# %%
# Assuming you have a pandas DataFrame called df with categorical variables
categorical_vars = ['Ship Mode', 'Segment', 'Region', 'Category', 'Sub-Category', 'Order Priority']

for var in categorical_vars:
    category_counts = Global_Df[var].value_counts()

    # Create a bar chart or pie chart based on the nature of the variable
    if len(category_counts) <= 10:
        # Bar chart for nominal variables with fewer categories
        category_counts.plot(kind='bar', figsize=(8, 6))
        plt.xlabel(var)
        plt.ylabel('Frequency')
        plt.title(f'{var} Distribution')
        plt.xticks(rotation=0)
        plt.show()
    else:
        # Pie chart for ordinal variables with more categories
        category_counts.plot(kind='pie', figsize=(30, 10), autopct='%0.1f%%',textprops={'fontsize': 12})
        
        plt.ylabel('')
        plt.title(f'{var} Distribution')
        plt.show()

# %%
# Sales of state
Sales_State  = Global_Df.groupby('State')['Sales'].sum().reset_index()
plt.figure(figsize=(30, 20))

x = Sales_State['State']
y = Sales_State ['Sales']
plt.bar(x,y,color='green')
 # Red color for negative values
plt.xlabel('State',fontsize=25)
plt.ylabel('Sales',fontsize=25)
plt.title('Sales by State',fontsize=30)
plt.xticks(rotation=90,fontsize=20)
plt.yticks(fontsize=20)

plt.show()

# %%
contingency_table_Cat_Sub_Cat = pd.crosstab(Global_Df['Category'], Global_Df['Sub-Category'])
contingency_table_Cat_Sub_Cat.plot(kind='bar', stacked=True, figsize=(8, 6))
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Contingency Table')
plt.xticks(rotation=0)
plt.legend(title='Sub-Category', bbox_to_anchor=(1, 1))
plt.show()

# %%
contingency_table_Cat_Ord = pd.crosstab(Global_Df['Category'], Global_Df['Order Priority'])
contingency_table_Cat_Ord.plot(kind='bar', stacked=True, figsize=(8, 6))
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Contingency Table')
plt.xticks(rotation=0)
plt.legend(title='Sub-Category', bbox_to_anchor=(1, 1))
plt.show()

# %%
contingency_table_Cat_State = pd.crosstab(Global_Df['Category'], Global_Df['State'])
contingency_table_Cat_State.plot(kind='bar', stacked=True, figsize=(8, 13))
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Contingency Table')
plt.xticks(rotation=0)
plt.legend(title='Sub-Category', bbox_to_anchor=(1, 1))
plt.show()

# %%
contingency_table_Cat_Reg = pd.crosstab(Global_Df['Category'], Global_Df['Region'])
contingency_table_Cat_Reg.plot(kind='bar', stacked=True, figsize=(8, 6))
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Contingency Table')
plt.xticks(rotation=0)
plt.legend(title='Sub-Category', bbox_to_anchor=(1, 1))
plt.show()

# %%
contingency_table_Cat_SM = pd.crosstab(Global_Df['Category'], Global_Df['Ship Mode'])
contingency_table_Cat_SM.plot(kind='bar', stacked=True, figsize=(8, 6))
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Contingency Table')
plt.xticks(rotation=0)
plt.legend(title='Sub-Category', bbox_to_anchor=(1, 1))
plt.show()

# %%
contingency_table_Cat_Seg = pd.crosstab(Global_Df['Category'], Global_Df['Segment'])
contingency_table_Cat_Seg.plot(kind='bar', stacked=True, figsize=(8, 6))
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Contingency Table')
plt.xticks(rotation=0)
plt.legend(title='Sub-Category', bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# <div style="font-size:30px; text-align:center">Time period</div>

# %%
Global_Df['Ship Date'] = pd.to_datetime(Global_Df['Ship Date'])
Global_Df['Order Date'] = pd.to_datetime(Global_Df['Order Date'])

Global_Df.sort_values(by='Order Date', inplace=True)

plt.plot(Global_Df['Order Date'], Global_Df['Ship Date'])
plt.xlabel('Order Date')
plt.ylabel('Ship Date')
plt.title('Ship Date vs Order Date')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Windows\Temp\ipykernel_3584\4018138748.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   Global_Df['Ship Date'] = pd.to_datetime(Global_Df['Ship Date'])
# C:\Windows\Temp\ipykernel_3584\4018138748.py:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   Global_Df['Order Date'] = pd.to_datetime(Global_Df['Order Date'])

# %%
data_agg = Global_Df.groupby(pd.Grouper(key='Order Date', freq='M')).count()

plt.plot(data_agg.index, data_agg['Ship Date'])
plt.xlabel('Order Date')
plt.ylabel('Number of Shipments')
plt.title('Trends of Shipments over Month')
plt.xticks(rotation=45)
plt.show()

# %%
data_agg = Global_Df.groupby(pd.Grouper(key='Order Date', freq='Q')).count()

plt.plot(data_agg.index, data_agg['Ship Date'])
plt.xlabel('Order Date')
plt.ylabel('Number of Shipments')
plt.title('Trends of Shipments over Quarters')
plt.xticks(rotation=45)
plt.show()

# %%
data_agg = Global_Df.groupby(pd.Grouper(key='Order Date', freq='Y')).count()

plt.plot(data_agg.index, data_agg['Ship Date'])
plt.xlabel('Order Date')
plt.ylabel('Number of Shipments')
plt.title('Trends of Shipments over Year')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <div style="font-size:30px;text-align:center">Profit</div>

# %%
# Profit by State
Profit_State  = Global_Df.groupby('State')['Profit'].sum().reset_index()
plt.figure(figsize=(30, 20))
x = Profit_State['State']
y = Profit_State ['Profit']
colors = ['red' if val < 0 else 'green' for val in y]
plt.bar(x,y,color=colors)
plt.xlabel('State',fontsize=25)
plt.ylabel('Profit',fontsize=25)
plt.title('Profit by State',fontsize=30)
plt.xticks(rotation=90,fontsize=20)
plt.yticks(fontsize=20)
plt.show()

# %%
Profit_Region  = Global_Df.groupby('Region')['Profit'].sum().reset_index()
x = Profit_Region['Region']
y = Profit_Region ['Profit']
colors = ['red' if val < 0 else 'green' for val in y]
plt.bar(x,y,color=colors)
plt.xlabel('Region',fontsize=15)
plt.ylabel('Profit',fontsize=15)
plt.title('Profit by Region',fontsize=20)
plt.xticks(rotation=0,fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
Profit_Cat  = Global_Df.groupby('Category')['Profit'].sum().reset_index()
x = Profit_Cat['Category']
y = Profit_Cat ['Profit']
colors = ['red' if val < 0 else 'green' for val in y]
plt.bar(x,y,color=colors)
plt.xlabel('Profit_Cat',fontsize=15)
plt.ylabel('Profit',fontsize=15)
plt.title('Profit by Profit_Cat',fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
Profit_Order_Priority  = Global_Df.groupby('Order Priority')['Profit'].sum().reset_index()
plt.figure(figsize=(10, 5))
x = Profit_Order_Priority['Order Priority']
y = Profit_Order_Priority ['Profit']
colors = ['red' if val < 0 else 'green' for val in y]
plt.bar(x,y,color=colors)
plt.xlabel('Profit_Order_Priority',fontsize=15)
plt.ylabel('Profit',fontsize=15)
plt.title('Profit by Profit_Order_Priority',fontsize=20)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
Profit_Sub_Cat  = Global_Df.groupby('Sub-Category')['Profit'].sum().reset_index()
plt.figure(figsize=(20, 5))
x = Profit_Sub_Cat['Sub-Category']
y = Profit_Sub_Cat ['Profit']
colors = ['red' if val < 0 else 'green' for val in y]
plt.bar(x,y,color=colors)
plt.xlabel('Profit_Sub_Cat',fontsize=15)
plt.ylabel('Profit',fontsize=15)
plt.title('Profit by Profit_Sub_Cat',fontsize=20)
plt.xticks(rotation=0,fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
Profit_Ship_Mode  = Global_Df.groupby('Ship Mode')['Profit'].sum().reset_index()
# plt.figure(figsize=(10, 5))
x = Profit_Ship_Mode['Ship Mode']
y = Profit_Ship_Mode ['Profit']
colors = ['red' if val < 0 else 'green' for val in y]
plt.bar(x,y,color=colors)
plt.xlabel('Profit_Ship_Mode')
plt.ylabel('Profit')
plt.title('Profit by Profit_Ship_Mode')
plt.xticks(fontsize=10)

plt.show()
